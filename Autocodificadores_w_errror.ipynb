# %%
import pandas as pd

# %%
# Leer el archivo CSV
df = pd.read_csv("./data/UK_foods.csv")

# Transponer el DataFrame
df_transposed = df.T

# Convertir la primera fila transpuesta en el encabezado y eliminarla del cuerpo del DataFrame
new_header = df_transposed.iloc[0]
df_transposed = df_transposed[1:]
df_transposed.columns = new_header

# Resetea el índice
df_transposed = df_transposed.reset_index()

# Cambiar el nombre de la nueva columna creada por el reset_index, si lo deseas
data = df_transposed.rename(columns={"index": "Country"})


# Opcional: Guardar el DataFrame transpuesto en un nuevo archivo CSV
# df_transposed.to_csv('archivo_transpuesto.csv', index=False)

data.head()
# Out:
# Product    Country Cheese Carcass_meat  Other_meat  Fish Fats_and_oils
# 0          England    105           245         685  147            193  \
# 1            Wales    103           227         803  160            235
# 2         Scotland    103           242         750  122            184
# 3        N.Ireland     66           267         586   93            209
#
# Product Sugars Fresh_potatoes  Fresh_Veg  Other_Veg  Processed_potatoes
# 0          156             720        253        488                 198  \
# 1          175             874        265        570                 203
# 2          147             566        171        418                 220
# 3          139            1033        143        355                 187
#
# Product Processed_Veg  Fresh_fruit  Cereals  Beverages Soft_drinks
# 0                  360         1102     1472        57         1374  \
# 1                  365         1137     1582        73         1256
# 2                  337          957     1462        53         1572
# 3                  334          674     1494        47         1506
#
# Product Alcoholic_drinks  Confectionery
# 0                     375             54
# 1                     475             64
# 2                     458             62
# 3                     135             41

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import pandas as pd  # Asegúrate de importar pandas ya que es necesario para manipulación de datos.

# Definición de las dimensiones de entrada y codificadas
input_dim = 17
encoding_dim = 2

# Definición del encoder
input_layer = keras.layers.Input(shape=(input_dim,))
encoded = keras.layers.Dense(encoding_dim, activation='relu')(input_layer)

# Definición del decoder
decoded = keras.layers.Dense(input_dim, activation='sigmoid')(encoded)

# Creación del modelo de autoencoder completo
autoencoder = keras.models.Model(input_layer, decoded)

# Creación del modelo de encoder
encoder = keras.models.Model(input_layer, encoded)

# %%
# Compilación del modelo
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Normalización de datos y preparación de etiquetas
scaler = MinMaxScaler()
labels = data["Country"].values
data = data.drop("Country", axis=1)
data_normalized = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)

x_train = data_normalized.values
x_train = x_train.astype('float32')

# Entrenamiento del modelo
autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_train, x_train))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.1698 - val_loss: 0.1696
# Epoch 2/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1696 - val_loss: 0.1694
# Epoch 3/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1694 - val_loss: 0.1692
# Epoch 4/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1692 - val_loss: 0.1690
# Epoch 5/50
# 1/1 [==============================] - 0s 98ms/step - loss: 0.1690 - val_loss: 0.1688
# Epoch 6/50
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1688 - val_loss: 0.1686
# Epoch 7/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1686 - val_loss: 0.1684
# Epoch 8/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1684 - val_loss: 0.1682
# Epoch 9/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1682 - val_loss: 0.1680
# Epoch 10/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1680 - val_loss: 0.1678
# Epoch 11/50
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1678 - val_loss: 0.1676
# Epoch 12/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1676 - val_loss: 0.1674
# Epoch 13/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1674 - val_loss: 0.1672
# Epoch 14/50
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1672 - val_loss: 0.1670
# Epoch 15/50
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1670 - val_loss: 0.1668
# Epoch 16/50
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1668 - val_loss: 0.1667
# Epoch 17/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1667 - val_loss: 0.1665
# Epoch 18/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1665 - val_loss: 0.1663
# Epoch 19/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1663 - val_loss: 0.1661
# Epoch 20/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1661 - val_loss: 0.1659
# Epoch 21/50
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1659 - val_loss: 0.1658
# Epoch 22/50
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1658 - val_loss: 0.1656
# Epoch 23/50
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1656 - val_loss: 0.1654
# Epoch 24/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1654 - val_loss: 0.1652
# Epoch 25/50
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1652 - val_loss: 0.1651
# Epoch 26/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1651 - val_loss: 0.1649
# Epoch 27/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1649 - val_loss: 0.1647
# Epoch 28/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1647 - val_loss: 0.1646
# Epoch 29/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1646 - val_loss: 0.1644
# Epoch 30/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1644 - val_loss: 0.1642
# Epoch 31/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1642 - val_loss: 0.1641
# Epoch 32/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1641 - val_loss: 0.1639
# Epoch 33/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1639 - val_loss: 0.1637
# Epoch 34/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1637 - val_loss: 0.1636
# Epoch 35/50
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1636 - val_loss: 0.1634
# Epoch 36/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1634 - val_loss: 0.1633
# Epoch 37/50
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1633 - val_loss: 0.1631
# Epoch 38/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1631 - val_loss: 0.1630
# Epoch 39/50
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1630 - val_loss: 0.1628
# Epoch 40/50
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1628 - val_loss: 0.1626
# Epoch 41/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1626 - val_loss: 0.1625
# Epoch 42/50
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1625 - val_loss: 0.1623
# Epoch 43/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1623 - val_loss: 0.1622
# Epoch 44/50
# 1/1 [==============================] - 0s 117ms/step - loss: 0.1622 - val_loss: 0.1620
# Epoch 45/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1620 - val_loss: 0.1619
# Epoch 46/50
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1619 - val_loss: 0.1617
# Epoch 47/50
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1617 - val_loss: 0.1616
# Epoch 48/50
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1616 - val_loss: 0.1615
# Epoch 49/50
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1615 - val_loss: 0.1613
# Epoch 50/50
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1613 - val_loss: 0.1612

# %%
# Realización de predicciones y cálculo de errores de reconstrucción
reconstructed_data = autoencoder.predict(x_train)
reconstruction_error_per_instance = np.mean(np.square(x_train - reconstructed_data), axis=1)
mean_reconstruction_error = np.mean(reconstruction_error_per_instance)

# Visualización de los datos codificados
encoded_data = encoder.predict(x_train)
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

print(reconstruction_error_per_instance)
print(mean_reconstruction_error)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# [0.07231114 0.21092737 0.14808537 0.21333128]
# 0.16116379

# %%
import matplotlib.pyplot as plt  # Asegúrate de importar matplotlib para la visualización.

unique_labels = np.unique(encoded_labels)
colors = plt.cm.jet(np.linspace(0, 1, len(unique_labels)))

for i, label in enumerate(unique_labels):
    subset = encoded_data[encoded_labels == label]
    plt.scatter(subset[:, 0], subset[:, 1], s=30, c=[colors[i]], label=label_encoder.inverse_transform([label])[0])

plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Datos codificados en 2D con etiquetas')
plt.legend()
plt.show()
